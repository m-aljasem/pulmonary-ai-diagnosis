# %% [markdown]
# # Comprehensive Data Exploration: Chest X-ray Multi-condition Classification
#
# This notebook provides detailed analysis of the dataset for model development.
#
# ## Objectives
# - Understand dataset structure and characteristics
# - Analyze class distributions and imbalances
# - Examine data quality and preprocessing needs
# - Prepare data for deep learning training

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Dataset Loading

# %%
# Load dataset
data_path = Path('../data')
print(f'Loading data from: {data_path}')

# Adjust based on your data structure
# For image datasets:
# df = pd.read_csv(data_path / 'metadata.csv')
# Or load from directory structure

print('Dataset structure will be displayed here')

# %% [markdown]
# ## 2. Data Statistics

# %%
# Calculate and display statistics
# if 'df' in locals():
#     print(f'Total samples: {len(df)}')
#     print(f'Features: {len(df.columns)}')
#     print('\n' + '='*60)
#     print(df.describe())
#     print('\n' + '='*60)
#     print(df.info())

# %% [markdown]
# ## 3. Class Distribution Analysis

# %%
# Analyze class distribution
# num_classes = 14
# if 'label' in df.columns or 'class' in df.columns:
#     label_col = 'label' if 'label' in df.columns else 'class'
#     class_counts = df[label_col].value_counts().sort_index()
#     
#     print('Class Distribution:')
#     print('-' * 40)
#     for cls, count in class_counts.items():
#         pct = count / len(df) * 100
#         print(f'Class {cls}: {count} ({pct:.1f}%)')
#     
#     # Visualize
#     fig, axes = plt.subplots(1, 2, figsize=(14, 5))
#     
#     axes[0].bar(class_counts.index, class_counts.values, color='steelblue')
#     axes[0].set_title('Class Distribution', fontsize=14, fontweight='bold')
#     axes[0].set_xlabel('Class', fontsize=12)
#     axes[0].set_ylabel('Count', fontsize=12)
#     axes[0].grid(True, alpha=0.3, axis='y')
#     
#     axes[1].pie(class_counts.values, labels=class_counts.index, autopct='%1.1f%%', startangle=90)
#     axes[1].set_title('Class Proportions', fontsize=14, fontweight='bold')
#     
#     plt.tight_layout()
#     plt.show()

# %% [markdown]
# ## 4. Data Quality Assessment

# %%
# Check for missing values, duplicates, etc.
# if 'df' in locals():
#     missing = df.isnull().sum()
#     if missing.sum() > 0:
#         print('Missing Values:')
#         print(missing[missing > 0])
#     else:
#         print('✓ No missing values')
#     
#     duplicates = df.duplicated().sum()
#     print(f'\nDuplicate rows: {duplicates}')
#     
#     print('\n✓ Data quality assessment complete')

# %% [markdown]
# ## 5. Summary and Insights

# %%
print('=' * 60)
print('DATA EXPLORATION SUMMARY')
print('=' * 60)
print('Project: Chest X-ray Multi-condition Classification')
print('Model Type: Multi-label CNN')
print('Number of Classes: 14')
print('\nData is ready for model training!')
